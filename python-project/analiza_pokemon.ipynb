# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/26/5d/1e13b597ed8e54803e9ac6ded18c04cd35d8cbc49016778ec50c4ca9e9d5/plotly-5.16.1-py2.py3-none-any.whl.metadata
#   Downloading plotly-5.16.1-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Obtaining dependency information for tenacity>=6.2.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: packaging in c:\users\grazy\appdata\roaming\python\python311\site-packages (from plotly) (23.0)
# Downloading plotly-5.16.1-py2.py3-none-any.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.1/15.6 MB 787.7 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/15.6 MB 901.1 kB/s eta 0:00:18
#     --------------------------------------- 0.3/15.6 MB 1.4 MB/s eta 0:00:11
#     --------------------------------------- 0.4/15.6 MB 1.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/15.6 MB 1.9 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/15.6 MB 2.0 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/15.6 MB 2.4 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/15.6 MB 2.4 MB/s eta 0:00:07
#    -- ------------------------------------- 1.1/15.6 MB 2.5 MB/s eta 0:00:06
#    --- ------------------------------------ 1.3/15.6 MB 2.5 MB/s eta 0:00:06
#    --- ------------------------------------ 1.4/15.6 MB 2.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/15.6 MB 2.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.8/15.6 MB 2.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.0/15.6 MB 2.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.1/15.6 MB 3.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.3/15.6 MB 3.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.3/15.6 MB 3.0 MB/s eta 0:00:05
#    ------ --------------------------------- 2.6/15.6 MB 3.0 MB/s eta 0:00:05
#    ------- -------------------------------- 2.7/15.6 MB 3.0 MB/s eta 0:00:05
#    ------- -------------------------------- 2.9/15.6 MB 3.0 MB/s eta 0:00:05
#    ------- -------------------------------- 2.9/15.6 MB 2.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.9/15.6 MB 2.8 MB/s eta 0:00:05
#    ------- -------------------------------- 3.1/15.6 MB 2.8 MB/s eta 0:00:05
#    -------- ------------------------------- 3.2/15.6 MB 2.8 MB/s eta 0:00:05
#    -------- ------------------------------- 3.2/15.6 MB 2.8 MB/s eta 0:00:05
#    -------- ------------------------------- 3.4/15.6 MB 2.8 MB/s eta 0:00:05
#    -------- ------------------------------- 3.5/15.6 MB 2.7 MB/s eta 0:00:05
#    --------- ------------------------------ 3.5/15.6 MB 2.7 MB/s eta 0:00:05
#    --------- ------------------------------ 3.5/15.6 MB 2.7 MB/s eta 0:00:05
#    --------- ------------------------------ 3.7/15.6 MB 2.6 MB/s eta 0:00:05
#    --------- ------------------------------ 3.8/15.6 MB 2.6 MB/s eta 0:00:05
#    --------- ------------------------------ 3.9/15.6 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.9/15.6 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.0/15.6 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.1/15.6 MB 2.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.1/15.6 MB 2.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/15.6 MB 2.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.3/15.6 MB 2.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.3/15.6 MB 2.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.4/15.6 MB 2.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.5/15.6 MB 2.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.5/15.6 MB 2.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.6/15.6 MB 2.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.7/15.6 MB 2.3 MB/s eta 0:00:05
#    ------------ --------------------------- 4.8/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------ --------------------------- 4.8/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------ --------------------------- 4.9/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------ --------------------------- 5.0/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------ --------------------------- 5.0/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.1/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.2/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.3/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.4/15.6 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.4/15.6 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.5/15.6 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.6/15.6 MB 2.2 MB/s eta 0:00:05
#    -------------- ------------------------- 5.7/15.6 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.7/15.6 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.8/15.6 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 5.9/15.6 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 6.0/15.6 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 6.0/15.6 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 6.1/15.6 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 6.2/15.6 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.3/15.6 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.3/15.6 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.4/15.6 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.5/15.6 MB 2.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.6/15.6 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.6/15.6 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.7/15.6 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.8/15.6 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.9/15.6 MB 2.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.9/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.0/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.1/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.1/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.2/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.3/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------ --------------------- 7.4/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.5/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.5/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.5/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.6/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.7/15.6 MB 2.0 MB/s eta 0:00:05
#    ------------------- -------------------- 7.8/15.6 MB 2.0 MB/s eta 0:00:04
#    -------------------- ------------------- 7.8/15.6 MB 1.9 MB/s eta 0:00:04
#    -------------------- ------------------- 7.9/15.6 MB 1.9 MB/s eta 0:00:04
#    -------------------- ------------------- 8.0/15.6 MB 1.9 MB/s eta 0:00:04
#    -------------------- ------------------- 8.1/15.6 MB 1.9 MB/s eta 0:00:04
#    -------------------- ------------------- 8.2/15.6 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 8.2/15.6 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 8.3/15.6 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 8.4/15.6 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 8.5/15.6 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 8.5/15.6 MB 1.9 MB/s eta 0:00:04
#    --------------------- ------------------ 8.6/15.6 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.6/15.6 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.7/15.6 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.8/15.6 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.8/15.6 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.9/15.6 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.0/15.6 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.0/15.6 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.1/15.6 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.2/15.6 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.2/15.6 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.3/15.6 MB 1.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 9.3/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.4/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.4/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.5/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.5/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.5/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.6/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.6/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.7/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------ --------------- 9.7/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 9.7/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 9.8/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 9.8/15.6 MB 1.8 MB/s eta 0:00:04
#    ------------------------- -------------- 9.8/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 9.9/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 9.9/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 9.9/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 10.0/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 10.0/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 10.0/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 10.1/15.6 MB 1.7 MB/s eta 0:00:04
#    ------------------------- -------------- 10.1/15.6 MB 1.7 MB/s eta 0:00:04
#    -------------------------- ------------- 10.2/15.6 MB 1.7 MB/s eta 0:00:04
#    -------------------------- ------------- 10.2/15.6 MB 1.7 MB/s eta 0:00:04
#    -------------------------- ------------- 10.3/15.6 MB 1.7 MB/s eta 0:00:04
#    -------------------------- ------------- 10.4/15.6 MB 1.7 MB/s eta 0:00:04
#    -------------------------- ------------- 10.5/15.6 MB 1.7 MB/s eta 0:00:04
#    --------------------------- ------------ 10.6/15.6 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 10.6/15.6 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 10.7/15.6 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 10.8/15.6 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 10.8/15.6 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.9/15.6 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.0/15.6 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.0/15.6 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.2/15.6 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.2/15.6 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.3/15.6 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.4/15.6 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.5/15.6 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.6/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------ --------- 11.7/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------ --------- 11.8/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------ --------- 11.9/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------ --------- 12.0/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.1/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.2/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.2/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.4/15.6 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 12.4/15.6 MB 1.6 MB/s eta 0:00:03
#    -------------------------------- ------- 12.6/15.6 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.6/15.6 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.7/15.6 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 12.8/15.6 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 12.9/15.6 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 13.0/15.6 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 13.1/15.6 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 13.2/15.6 MB 1.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.3/15.6 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.4/15.6 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.5/15.6 MB 1.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.6/15.6 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.7/15.6 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.8/15.6 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.8/15.6 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 13.9/15.6 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.0/15.6 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------ --- 14.1/15.6 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.6 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 14.3/15.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.5/15.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.5/15.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.6 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.6 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.6 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.6 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.3/15.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 1.6 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.16.1 tenacity-8.2.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import plotly.express as px

# %%
df = pd.read_csv('pokemon.csv')

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
pokemon_hp = df.groupby('name')['hp'].sum().reset_index().sort_values('hp',ascending=False)
boxhp = px.box(pokemon_hp, y='hp')
# boxhp = update_layout(title='Range of Pokemon with their HP')
boxhp.show()

# %%
barhp = px.bar(pokemon_hp[:21], y='hp', x='name', color='hp', height=600)
barhp.show()

# %%
pokemon_hp = df.groupby('name')['attack'].sum().reset_index().sort_values('attack',ascending=False)
boxattack = px.box(pokemon_hp, y='attack')
# boxhp = update_layout(title='Range of Pokemon with their HP')
boxattack.show()

# %%
barattack = px.bar(pokemon_hp[:5], y='attack', x='name', color='attack', height=600)
barattack.show()

# %%
pokemon_hp = df.groupby('name')['sp_attack'].sum().reset_index().sort_values('sp_attack',ascending=False)
boxspattack = px.box(pokemon_hp, y='sp_attack')
# boxhp = update_layout(title='Range of Pokemon with their HP')
boxspattack.show()

# %%
barspattack = px.bar(pokemon_hp[:10], y='sp_attack', x='name', color='sp_attack', height=600)
barspattack.show()

# %%
pokemon_hp = df.groupby('name')['defense'].sum().reset_index().sort_values('defense',ascending=False)
boxdefence = px.box(pokemon_hp, y='defense')
# boxhp = update_layout(title='Range of Pokemon with their HP')
boxdefence.show()

# %%
bardefense = px.bar(pokemon_hp[:11], y='defense', x='name', color='defense', height=600)
bardefense.show()

# %%
pokemon_hp = df.groupby('name')['sp_defense'].sum().reset_index().sort_values('sp_defense',ascending=False)
boxspdefence = px.box(pokemon_hp, y='sp_defense')
# boxhp = update_layout(title='Range of Pokemon with their HP')
boxspdefence.show()

# %%
barspdefense = px.bar(pokemon_hp[:11], y='sp_defense', x='name', color='sp_defense', height=600)
barspdefense.show()

# %%
pokemon_hp = df.groupby('name')['speed'].sum().reset_index().sort_values('speed',ascending=False)
boxspeed = px.box(pokemon_hp, y='speed')
# boxhp = update_layout(title='Range of Pokemon with their HP')
boxspeed.show()

# %%
barspeed = px.bar(pokemon_hp[:9], y='speed', x='name', color='speed', height=600)
barspeed.show()
